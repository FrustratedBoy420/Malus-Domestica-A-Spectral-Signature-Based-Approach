# %%
# %pip install tensorflow
# %pip install opencv-python
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import matplotlib.pyplot as plt

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    'Dataset/Valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 14 files belonging to 2 classes.

# %%
cnn = tf.keras.models.load_model('trained_plant_disease_model.keras')

# %%
image_path = 'Dataset/Valid/Healthy/healthy_11.JPG'

img = cv2.imread(image_path)

if img is not None:
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

    plt.imshow(img)
    plt.title('Test Image')
    plt.xticks([])
    plt.yticks([])
    plt.show()
else:
    print(f"Error: Could not load image from path: {image_path}")

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(128,128))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])
predictions = cnn.predict(input_arr)
print(predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 880ms/step
# [[9.9971396e-01 2.8598050e-04]]

# %%
result_index = np.argmax(predictions)
print(result_index)
# Out:
# 0

# %%
class_name=validation_set.class_names
model_prediction = class_name[result_index]
plt.imshow(img)
plt.title(f"Disease Name: {model_prediction}")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
cnn = tf.keras.models.load_model('trained_plant_disease_model.keras')

# %%
image_path_2 = 'Dataset/Valid/Infected/infected_04.JPG'

img_2= cv2.imread(image_path_2)

if img_2 is not None:
    img_2 = cv2.cvtColor(img_2,cv2.COLOR_BGR2RGB)

    plt.imshow(img_2)
    plt.title('Test Image')
    plt.xticks([])
    plt.yticks([])
    plt.show()
else:
    print(f"Error: Could not load image from path: {image_path_2}")

# %%
image_2= tf.keras.preprocessing.image.load_img(image_path_2,target_size=(128,128))
input_arr = tf.keras.preprocessing.image.img_to_array(image_2)
input_arr = np.array([input_arr])
predictions= cnn.predict(input_arr)
print(predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# [[2.2695067e-05 9.9997735e-01]]

# %%
result_index = np.argmax(predictions)
print(result_index)
# Out:
# 1

# %%
model_prediction_2 = class_name[result_index]
plt.imshow(img_2)
plt.title(f"Disease Name: {model_prediction_2}")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
cnn = tf.keras.models.load_model('trained_plant_disease_model.keras')

# %%
image_path_2 = 'Dataset/Valid/Infected/infected_09.JPG'

img_2= cv2.imread(image_path_2)

if img_2 is not None:
    img_2 = cv2.cvtColor(img_2,cv2.COLOR_BGR2RGB)

    plt.imshow(img_2)
    plt.title('Test Image')
    plt.xticks([])
    plt.yticks([])
    plt.show()
else:
    print(f"Error: Could not load image from path: {image_path_2}")

# %%
image_2= tf.keras.preprocessing.image.load_img(image_path_2,target_size=(128,128))
input_arr = tf.keras.preprocessing.image.img_to_array(image_2)
input_arr = np.array([input_arr])
predictions= cnn.predict(input_arr)
print(predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# [[0.00103904 0.998961  ]]

# %%
result_index = np.argmax(predictions)
print(result_index)
# Out:
# 1

# %%
model_prediction_2 = class_name[result_index]
plt.imshow(img_2)
plt.title(f"Disease Name: {model_prediction_2}")
plt.xticks([])
plt.yticks([])
plt.show()
